# %%
import joblib
import pandas as pd

# Load the trained model
model = joblib.load('best_model.pkl')

# Create 3 hardcoded test cases
test_data = pd.DataFrame({
    'hour': [8, 15, 20],  # Hour of delivery
    'day_of_week': [1, 3, 5],  # Days of week (0=Monday, 6=Sunday)
    'month': [12, 5, 10],  # Months
    'number_of_obstacles': [1, 3, 22]  # Obstacles encountered
})

# Perform prediction with the trained model
predictions = model.predict(test_data)

# Display results
for i, prediction in enumerate(predictions):
    row = test_data.iloc[i]
    print(
        f"Prediction {i+1}:\n"
        f"Hour = {row['hour']}, "
        f"Day of Week = {row['day_of_week']}, "
        f"Month = {row['month']}, "
        f"Obstacles = {row['number_of_obstacles']}\n"
        f"Predicted Delivery Time = {prediction[0]:.2f} minutes\n"
    )
# Out:
# Prediction 1:
# Hour = 8, Day of Week = 1, Month = 12, Obstacles = 1
# Predicted Delivery Time = 12.54 minutes
#
# Prediction 2:
# Hour = 15, Day of Week = 3, Month = 5, Obstacles = 3
# Predicted Delivery Time = 10.11 minutes
#
# Prediction 3:
# Hour = 20, Day of Week = 5, Month = 10, Obstacles = 22
# Predicted Delivery Time = 14.02 minutes
